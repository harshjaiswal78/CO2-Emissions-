# %% [markdown]
# # **Analysis on Co2 Emissions**

# %% [markdown]
# **In this document, our objective is to delve into the dataset and conduct an analysis of the trends in carbon dioxide (CO2) emissions over the years. Given that CO2 significantly contributes to global warming, our exploration aims to identify and understand which continent exhibits the highest CO2 emissions throughout the years. Through this investigation, we aim to shed light on the environmental impact of CO2 emissions on a continental scale.**

# %% [markdown]
# # **Index**
#
# 1. Importing Libraries
# 2. Data Exploration
# 3. Data Featuring
# 4. Data Analysis
# 5. Conclusion

# %% [markdown]
# # 1. **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import os

# %%
Main_data_set=pd.read_csv('/Users/harshjaiswal/Desktop/Git/C/production_based_co2_emissions.csv')

# %% [markdown]
# # 2. **Data Explorations**

# %%
Main_data_set
# Out:
#     ISO3              Country Continent           Hemisphere  \
# 0    AFG          Afghanistan      Asia  Northern Hemisphere
# 1    ALB              Albania    Europe  Northern Hemisphere
# 2    DZA              Algeria    Africa  Northern Hemisphere
# 3    AGO               Angola    Africa  Southern Hemisphere
# 4    ATG  Antigua and Barbuda   America  Northern Hemisphere
# ..   ...                  ...       ...                  ...
# 176  VEN            Venezuela   America  Northern Hemisphere
# 177  VNM              Vietnam      Asia  Northern Hemisphere
# 178  YEM                Yemen      Asia  Northern Hemisphere
# 179  ZMB               Zambia    Africa  Southern Hemisphere
# 180  ZWE             Zimbabwe    Africa  Southern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 0                                     1.24
# 1                                     3.56
# 2                                     3.50
# 3                                     4.29
# 4                                     6.31
# ..                                     ...
# 176                                   8.62
# 177                                   1.03
# 178                                   0.99
# 179                                   5.18
# 180                                   3.25
#
#      Metric tons of CO2e per capita (1995)  \
# 0                                     0.84
# 1                                     2.15
# 2                                     3.42
# 3                                     4.43
# 4                                     6.53
# ..                                     ...
# 176                                   8.73
# 177                                   1.25
# 178                                   1.00
# 179                                   4.20
# 180                                   2.62
#
#      Metric tons of CO2e per capita (2000)  \
# 0                                     0.82
# 1                                     2.36
# 2                                     3.75
# 3                                     4.20
# 4                                     7.08
# ..                                     ...
# 176                                   8.70
# 177                                   1.63
# 178                                   1.15
# 179                                   3.36
# 180                                   2.47
#
#      Metric tons of CO2e per capita (2005)  \
# 0                                     0.76
# 1                                     2.68
# 2                                     4.04
# 3                                     5.06
# 4                                     8.77
# ..                                     ...
# 176                                   8.85
# 177                                   2.16
# 178                                   1.33
# 179                                   3.58
# 180                                   1.93
#
#      Metric tons of CO2e per capita (2010)  \
# 0                                     1.06
# 1                                     2.83
# 2                                     4.58
# 3                                     6.32
# 4                                    10.69
# ..                                     ...
# 176                                   9.08
# 177                                   2.80
# 178                                   1.41
# 179                                   3.31
# 180                                   1.81
#
#      Metric tons of CO2e per capita (2013)  \
# 0                                     1.40
# 1                                     2.85
# 2                                     4.88
# 3                                     5.99
# 4                                    11.22
# ..                                     ...
# 176                                   8.85
# 177                                   2.81
# 178                                   1.39
# 179                                   3.31
# 180                                   1.82
#
#      Metric tons of CO2e per capita (2018)
# 0                                     2.66
# 1                                     3.52
# 2                                     5.18
# 3                                     2.59
# 4                                    12.59
# ..                                     ...
# 176                                   8.10
# 177                                   3.94
# 178                                   0.76
# 179                                   2.34
# 180                                   2.17
#
# [181 rows x 11 columns]

# %%
Main_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ISO3                                   181 non-null    object
#  1   Country                                181 non-null    object
#  2   Continent                              181 non-null    object
#  3   Hemisphere                             181 non-null    object
#  4   Metric tons of CO2e per capita (1990)  154 non-null    float64
#  5   Metric tons of CO2e per capita (1995)  177 non-null    float64
#  6   Metric tons of CO2e per capita (2000)  179 non-null    float64
#  7   Metric tons of CO2e per capita (2005)  179 non-null    float64
#  8   Metric tons of CO2e per capita (2010)  181 non-null    float64
#  9   Metric tons of CO2e per capita (2013)  180 non-null    float64
#  10  Metric tons of CO2e per capita (2018)  180 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 15.7+ KB

# %%
Main_data_set.isna().sum()
# Out:
# ISO3                                      0
# Country                                   0
# Continent                                 0
# Hemisphere                                0
# Metric tons of CO2e per capita (1990)    27
# Metric tons of CO2e per capita (1995)     4
# Metric tons of CO2e per capita (2000)     2
# Metric tons of CO2e per capita (2005)     2
# Metric tons of CO2e per capita (2010)     0
# Metric tons of CO2e per capita (2013)     1
# Metric tons of CO2e per capita (2018)     1
# dtype: int64

# %% [markdown]
# # 3. **Data Featuring**

# %%
Main_data_set[Main_data_set['Metric tons of CO2e per capita (1990)'].isna()]
# Out:
#     ISO3                 Country Continent           Hemisphere  \
# 6    ARM                 Armenia      Asia  Northern Hemisphere
# 9    AZE              Azerbaijan      Asia  Northern Hemisphere
# 14   BLR                 Belarus    Europe  Northern Hemisphere
# 15   BEL                 Belgium    Europe  Northern Hemisphere
# 20   BIH  Bosnia and Herzegovina    Europe  Northern Hemisphere
# 38   HRV                 Croatia    Europe  Northern Hemisphere
# 41   CZE          Czech Republic    Europe  Northern Hemisphere
# 50   ERI                 Eritrea    Africa  Northern Hemisphere
# 51   EST                 Estonia    Europe  Northern Hemisphere
# 53   ETH                Ethiopia    Africa  Northern Hemisphere
# 59   GEO                 Georgia      Asia  Northern Hemisphere
# 83   KAZ              Kazakhstan      Asia  Northern Hemisphere
# 87   KGZ              Kyrgyzstan      Asia  Northern Hemisphere
# 89   LVA                  Latvia    Europe  Northern Hemisphere
# 94   LTU               Lithuania    Europe  Northern Hemisphere
# 95   LUX              Luxembourg    Europe  Northern Hemisphere
# 105  MDA                 Moldova    Europe  Northern Hemisphere
# 107  MNE              Montenegro    Europe  Northern Hemisphere
# 123  PLW                   Palau   Oceania  Northern Hemisphere
# 134  RUS                  Russia    Europe  Northern Hemisphere
# 143  SRB                  Serbia    Europe  Northern Hemisphere
# 147  SVK                Slovakia    Europe  Northern Hemisphere
# 148  SVN                Slovenia    Europe  Northern Hemisphere
# 159  TJK              Tajikistan      Asia  Northern Hemisphere
# 167  TKM            Turkmenistan      Asia  Northern Hemisphere
# 169  UKR                 Ukraine    Europe  Northern Hemisphere
# 174  UZB              Uzbekistan      Asia  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 6                                      NaN
# 9                                      NaN
# 14                                     NaN
# 15                                     NaN
# 20                                     NaN
# 38                                     NaN
# 41                                     NaN
# 50                                     NaN
# 51                                     NaN
# 53                                     NaN
# 59                                     NaN
# 83                                     NaN
# 87                                     NaN
# 89                                     NaN
# 94                                     NaN
# 95                                     NaN
# 105                                    NaN
# 107                                    NaN
# 123                                    NaN
# 134                                    NaN
# 143                                    NaN
# 147                                    NaN
# 148                                    NaN
# 159                                    NaN
# 167                                    NaN
# 169                                    NaN
# 174                                    NaN
#
#      Metric tons of CO2e per capita (1995)  \
# 6                                     1.94
# 9                                     7.50
# 14                                    8.23
# 15                                     NaN
# 20                                    1.81
# 38                                    4.64
# 41                                   14.05
# 50                                    1.96
# 51                                   14.40
# 53                                    1.11
# 59                                    2.88
# 83                                   14.43
# 87                                    2.06
# 89                                    5.43
# 94                                    6.07
# 95                                     NaN
# 105                                   4.12
# 107                                    NaN
# 123                                   6.98
# 134                                  14.45
# 143                                    NaN
# 147                                   9.36
# 148                                   8.92
# 159                                   1.28
# 167                                  13.39
# 169                                  10.41
# 174                                   7.90
#
#      Metric tons of CO2e per capita (2000)  \
# 6                                     1.82
# 9                                     6.79
# 14                                    7.84
# 15                                   13.26
# 20                                    5.34
# 38                                    5.41
# 41                                   13.76
# 50                                    1.95
# 51                                   13.53
# 53                                    1.09
# 59                                    2.78
# 83                                   10.37
# 87                                    1.85
# 89                                    4.66
# 94                                    5.55
# 95                                   21.14
# 105                                   2.60
# 107                                    NaN
# 123                                   6.74
# 134                                  13.92
# 143                                    NaN
# 147                                   8.48
# 148                                   9.01
# 159                                   0.98
# 167                                  14.51
# 169                                   8.25
# 174                                   8.40
#
#      Metric tons of CO2e per capita (2005)  \
# 6                                     2.30
# 9                                     6.61
# 14                                    8.63
# 15                                   12.16
# 20                                    6.00
# 38                                    6.40
# 41                                   13.47
# 50                                    1.63
# 51                                   15.77
# 53                                    1.16
# 59                                    2.61
# 83                                   13.73
# 87                                    1.97
# 89                                    5.47
# 94                                    6.51
# 95                                   27.86
# 105                                   2.91
# 107                                    NaN
# 123                                  10.30
# 134                                  14.70
# 143                                    NaN
# 147                                   8.68
# 148                                   9.67
# 159                                   1.04
# 167                                  18.13
# 169                                   8.54
# 174                                   7.85
#
#      Metric tons of CO2e per capita (2010)  \
# 6                                     2.46
# 9                                     6.36
# 14                                    9.66
# 15                                   11.44
# 20                                    7.36
# 38                                    5.99
# 41                                   12.39
# 50                                    1.44
# 51                                   17.30
# 53                                    1.31
# 59                                    2.91
# 83                                   17.28
# 87                                    2.16
# 89                                    6.29
# 94                                    6.65
# 95                                   23.82
# 105                                   3.02
# 107                                   5.81
# 123                                  11.64
# 134                                  15.21
# 143                                   6.54
# 147                                   7.90
# 148                                   9.30
# 159                                   1.10
# 167                                  19.44
# 169                                   8.13
# 174                                   7.55
#
#      Metric tons of CO2e per capita (2013)  \
# 6                                     2.97
# 9                                     7.43
# 14                                    9.55
# 15                                   10.17
# 20                                    7.89
# 38                                    5.49
# 41                                   11.42
# 50                                    1.44
# 51                                   17.66
# 53                                    1.30
# 59                                    3.66
# 83                                   18.23
# 87                                    2.73
# 89                                    6.20
# 94                                    6.45
# 95                                   20.72
# 105                                   2.82
# 107                                   5.40
# 123                                  17.03
# 134                                  15.31
# 143                                   6.62
# 147                                   7.43
# 148                                   8.72
# 159                                   1.25
# 167                                  20.93
# 169                                   8.33
# 174                                   7.52
#
#      Metric tons of CO2e per capita (2018)
# 6                                     3.17
# 9                                     8.07
# 14                                    9.29
# 15                                    9.52
# 20                                    8.18
# 38                                    5.52
# 41                                   11.56
# 50                                     NaN
# 51                                   14.07
# 53                                    1.58
# 59                                    4.54
# 83                                   15.00
# 87                                    2.87
# 89                                    6.05
# 94                                    6.73
# 95                                   16.81
# 105                                   4.87
# 107                                   6.11
# 123                                  17.93
# 134                                  17.60
# 143                                   8.96
# 147                                   7.33
# 148                                   8.28
# 159                                   1.67
# 167                                  21.38
# 169                                   6.15
# 174                                   7.15

# %%
Main_data_set[1:10]
# Out:
#   ISO3              Country Continent           Hemisphere  \
# 1  ALB              Albania    Europe  Northern Hemisphere
# 2  DZA              Algeria    Africa  Northern Hemisphere
# 3  AGO               Angola    Africa  Southern Hemisphere
# 4  ATG  Antigua and Barbuda   America  Northern Hemisphere
# 5  ARG            Argentina   America  Southern Hemisphere
# 6  ARM              Armenia      Asia  Northern Hemisphere
# 7  AUS            Australia   Oceania  Southern Hemisphere
# 8  AUT              Austria    Europe  Northern Hemisphere
# 9  AZE           Azerbaijan      Asia  Northern Hemisphere
#
#    Metric tons of CO2e per capita (1990)  \
# 1                                   3.56
# 2                                   3.50
# 3                                   4.29
# 4                                   6.31
# 5                                   7.12
# 6                                    NaN
# 7                                  28.06
# 8                                   9.71
# 9                                    NaN
#
#    Metric tons of CO2e per capita (1995)  \
# 1                                   2.15
# 2                                   3.42
# 3                                   4.43
# 4                                   6.53
# 5                                   7.25
# 6                                   1.94
# 7                                  27.28
# 8                                   9.55
# 9                                   7.50
#
#    Metric tons of CO2e per capita (2000)  \
# 1                                   2.36
# 2                                   3.75
# 3                                   4.20
# 4                                   7.08
# 5                                   7.49
# 6                                   1.82
# 7                                  30.84
# 8                                   9.59
# 9                                   6.79
#
#    Metric tons of CO2e per capita (2005)  \
# 1                                   2.68
# 2                                   4.04
# 3                                   5.06
# 4                                   8.77
# 5                                   7.73
# 6                                   2.30
# 7                                  27.60
# 8                                  10.79
# 9                                   6.61
#
#    Metric tons of CO2e per capita (2010)  \
# 1                                   2.83
# 2                                   4.58
# 3                                   6.32
# 4                                  10.69
# 5                                   7.77
# 6                                   2.46
# 7                                  25.39
# 8                                   9.85
# 9                                   6.36
#
#    Metric tons of CO2e per capita (2013)  \
# 1                                   2.85
# 2                                   4.88
# 3                                   5.99
# 4                                  11.22
# 5                                   7.86
# 6                                   2.97
# 7                                  25.06
# 8                                   9.15
# 9                                   7.43
#
#    Metric tons of CO2e per capita (2018)
# 1                                   3.52
# 2                                   5.18
# 3                                   2.59
# 4                                  12.59
# 5                                   8.22
# 6                                   3.17
# 7                                  24.63
# 8                                   8.48
# 9                                   8.07

# %%
Main_data_set[Main_data_set['Country']=='Armenia']
# Out:
#   ISO3  Country Continent           Hemisphere  \
# 6  ARM  Armenia      Asia  Northern Hemisphere
#
#    Metric tons of CO2e per capita (1990)  \
# 6                                    NaN
#
#    Metric tons of CO2e per capita (1995)  \
# 6                                   1.94
#
#    Metric tons of CO2e per capita (2000)  \
# 6                                   1.82
#
#    Metric tons of CO2e per capita (2005)  \
# 6                                    2.3
#
#    Metric tons of CO2e per capita (2010)  \
# 6                                   2.46
#
#    Metric tons of CO2e per capita (2013)  \
# 6                                   2.97
#
#    Metric tons of CO2e per capita (2018)
# 6                                   3.17

# %%
Main_data_set['Country'].value_counts()
# Out:
# Afghanistan    1
# Netherlands    1
# Nicaragua      1
# Niger          1
# Nigeria        1
#               ..
# Greece         1
# Grenada        1
# Guatemala      1
# Guinea         1
# Zimbabwe       1
# Name: Country, Length: 181, dtype: int64

# %%
Main_data_set['Continent'].value_counts()
# Out:
# Africa     51
# Asia       46
# Europe     38
# America    35
# Oceania    11
# Name: Continent, dtype: int64

# %%
Copy_data_set=Main_data_set.copy()

# %%
Copy_data_set
# Out:
#     ISO3              Country Continent           Hemisphere  \
# 0    AFG          Afghanistan      Asia  Northern Hemisphere
# 1    ALB              Albania    Europe  Northern Hemisphere
# 2    DZA              Algeria    Africa  Northern Hemisphere
# 3    AGO               Angola    Africa  Southern Hemisphere
# 4    ATG  Antigua and Barbuda   America  Northern Hemisphere
# ..   ...                  ...       ...                  ...
# 176  VEN            Venezuela   America  Northern Hemisphere
# 177  VNM              Vietnam      Asia  Northern Hemisphere
# 178  YEM                Yemen      Asia  Northern Hemisphere
# 179  ZMB               Zambia    Africa  Southern Hemisphere
# 180  ZWE             Zimbabwe    Africa  Southern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 0                                     1.24
# 1                                     3.56
# 2                                     3.50
# 3                                     4.29
# 4                                     6.31
# ..                                     ...
# 176                                   8.62
# 177                                   1.03
# 178                                   0.99
# 179                                   5.18
# 180                                   3.25
#
#      Metric tons of CO2e per capita (1995)  \
# 0                                     0.84
# 1                                     2.15
# 2                                     3.42
# 3                                     4.43
# 4                                     6.53
# ..                                     ...
# 176                                   8.73
# 177                                   1.25
# 178                                   1.00
# 179                                   4.20
# 180                                   2.62
#
#      Metric tons of CO2e per capita (2000)  \
# 0                                     0.82
# 1                                     2.36
# 2                                     3.75
# 3                                     4.20
# 4                                     7.08
# ..                                     ...
# 176                                   8.70
# 177                                   1.63
# 178                                   1.15
# 179                                   3.36
# 180                                   2.47
#
#      Metric tons of CO2e per capita (2005)  \
# 0                                     0.76
# 1                                     2.68
# 2                                     4.04
# 3                                     5.06
# 4                                     8.77
# ..                                     ...
# 176                                   8.85
# 177                                   2.16
# 178                                   1.33
# 179                                   3.58
# 180                                   1.93
#
#      Metric tons of CO2e per capita (2010)  \
# 0                                     1.06
# 1                                     2.83
# 2                                     4.58
# 3                                     6.32
# 4                                    10.69
# ..                                     ...
# 176                                   9.08
# 177                                   2.80
# 178                                   1.41
# 179                                   3.31
# 180                                   1.81
#
#      Metric tons of CO2e per capita (2013)  \
# 0                                     1.40
# 1                                     2.85
# 2                                     4.88
# 3                                     5.99
# 4                                    11.22
# ..                                     ...
# 176                                   8.85
# 177                                   2.81
# 178                                   1.39
# 179                                   3.31
# 180                                   1.82
#
#      Metric tons of CO2e per capita (2018)
# 0                                     2.66
# 1                                     3.52
# 2                                     5.18
# 3                                     2.59
# 4                                    12.59
# ..                                     ...
# 176                                   8.10
# 177                                   3.94
# 178                                   0.76
# 179                                   2.34
# 180                                   2.17
#
# [181 rows x 11 columns]

# %%
Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (1990)'].isna()]
# Out:
#     ISO3                 Country Continent           Hemisphere  \
# 6    ARM                 Armenia      Asia  Northern Hemisphere
# 9    AZE              Azerbaijan      Asia  Northern Hemisphere
# 14   BLR                 Belarus    Europe  Northern Hemisphere
# 15   BEL                 Belgium    Europe  Northern Hemisphere
# 20   BIH  Bosnia and Herzegovina    Europe  Northern Hemisphere
# 38   HRV                 Croatia    Europe  Northern Hemisphere
# 41   CZE          Czech Republic    Europe  Northern Hemisphere
# 50   ERI                 Eritrea    Africa  Northern Hemisphere
# 51   EST                 Estonia    Europe  Northern Hemisphere
# 53   ETH                Ethiopia    Africa  Northern Hemisphere
# 59   GEO                 Georgia      Asia  Northern Hemisphere
# 83   KAZ              Kazakhstan      Asia  Northern Hemisphere
# 87   KGZ              Kyrgyzstan      Asia  Northern Hemisphere
# 89   LVA                  Latvia    Europe  Northern Hemisphere
# 94   LTU               Lithuania    Europe  Northern Hemisphere
# 95   LUX              Luxembourg    Europe  Northern Hemisphere
# 105  MDA                 Moldova    Europe  Northern Hemisphere
# 107  MNE              Montenegro    Europe  Northern Hemisphere
# 123  PLW                   Palau   Oceania  Northern Hemisphere
# 134  RUS                  Russia    Europe  Northern Hemisphere
# 143  SRB                  Serbia    Europe  Northern Hemisphere
# 147  SVK                Slovakia    Europe  Northern Hemisphere
# 148  SVN                Slovenia    Europe  Northern Hemisphere
# 159  TJK              Tajikistan      Asia  Northern Hemisphere
# 167  TKM            Turkmenistan      Asia  Northern Hemisphere
# 169  UKR                 Ukraine    Europe  Northern Hemisphere
# 174  UZB              Uzbekistan      Asia  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 6                                      NaN
# 9                                      NaN
# 14                                     NaN
# 15                                     NaN
# 20                                     NaN
# 38                                     NaN
# 41                                     NaN
# 50                                     NaN
# 51                                     NaN
# 53                                     NaN
# 59                                     NaN
# 83                                     NaN
# 87                                     NaN
# 89                                     NaN
# 94                                     NaN
# 95                                     NaN
# 105                                    NaN
# 107                                    NaN
# 123                                    NaN
# 134                                    NaN
# 143                                    NaN
# 147                                    NaN
# 148                                    NaN
# 159                                    NaN
# 167                                    NaN
# 169                                    NaN
# 174                                    NaN
#
#      Metric tons of CO2e per capita (1995)  \
# 6                                     1.94
# 9                                     7.50
# 14                                    8.23
# 15                                     NaN
# 20                                    1.81
# 38                                    4.64
# 41                                   14.05
# 50                                    1.96
# 51                                   14.40
# 53                                    1.11
# 59                                    2.88
# 83                                   14.43
# 87                                    2.06
# 89                                    5.43
# 94                                    6.07
# 95                                     NaN
# 105                                   4.12
# 107                                    NaN
# 123                                   6.98
# 134                                  14.45
# 143                                    NaN
# 147                                   9.36
# 148                                   8.92
# 159                                   1.28
# 167                                  13.39
# 169                                  10.41
# 174                                   7.90
#
#      Metric tons of CO2e per capita (2000)  \
# 6                                     1.82
# 9                                     6.79
# 14                                    7.84
# 15                                   13.26
# 20                                    5.34
# 38                                    5.41
# 41                                   13.76
# 50                                    1.95
# 51                                   13.53
# 53                                    1.09
# 59                                    2.78
# 83                                   10.37
# 87                                    1.85
# 89                                    4.66
# 94                                    5.55
# 95                                   21.14
# 105                                   2.60
# 107                                    NaN
# 123                                   6.74
# 134                                  13.92
# 143                                    NaN
# 147                                   8.48
# 148                                   9.01
# 159                                   0.98
# 167                                  14.51
# 169                                   8.25
# 174                                   8.40
#
#      Metric tons of CO2e per capita (2005)  \
# 6                                     2.30
# 9                                     6.61
# 14                                    8.63
# 15                                   12.16
# 20                                    6.00
# 38                                    6.40
# 41                                   13.47
# 50                                    1.63
# 51                                   15.77
# 53                                    1.16
# 59                                    2.61
# 83                                   13.73
# 87                                    1.97
# 89                                    5.47
# 94                                    6.51
# 95                                   27.86
# 105                                   2.91
# 107                                    NaN
# 123                                  10.30
# 134                                  14.70
# 143                                    NaN
# 147                                   8.68
# 148                                   9.67
# 159                                   1.04
# 167                                  18.13
# 169                                   8.54
# 174                                   7.85
#
#      Metric tons of CO2e per capita (2010)  \
# 6                                     2.46
# 9                                     6.36
# 14                                    9.66
# 15                                   11.44
# 20                                    7.36
# 38                                    5.99
# 41                                   12.39
# 50                                    1.44
# 51                                   17.30
# 53                                    1.31
# 59                                    2.91
# 83                                   17.28
# 87                                    2.16
# 89                                    6.29
# 94                                    6.65
# 95                                   23.82
# 105                                   3.02
# 107                                   5.81
# 123                                  11.64
# 134                                  15.21
# 143                                   6.54
# 147                                   7.90
# 148                                   9.30
# 159                                   1.10
# 167                                  19.44
# 169                                   8.13
# 174                                   7.55
#
#      Metric tons of CO2e per capita (2013)  \
# 6                                     2.97
# 9                                     7.43
# 14                                    9.55
# 15                                   10.17
# 20                                    7.89
# 38                                    5.49
# 41                                   11.42
# 50                                    1.44
# 51                                   17.66
# 53                                    1.30
# 59                                    3.66
# 83                                   18.23
# 87                                    2.73
# 89                                    6.20
# 94                                    6.45
# 95                                   20.72
# 105                                   2.82
# 107                                   5.40
# 123                                  17.03
# 134                                  15.31
# 143                                   6.62
# 147                                   7.43
# 148                                   8.72
# 159                                   1.25
# 167                                  20.93
# 169                                   8.33
# 174                                   7.52
#
#      Metric tons of CO2e per capita (2018)
# 6                                     3.17
# 9                                     8.07
# 14                                    9.29
# 15                                    9.52
# 20                                    8.18
# 38                                    5.52
# 41                                   11.56
# 50                                     NaN
# 51                                   14.07
# 53                                    1.58
# 59                                    4.54
# 83                                   15.00
# 87                                    2.87
# 89                                    6.05
# 94                                    6.73
# 95                                   16.81
# 105                                   4.87
# 107                                   6.11
# 123                                  17.93
# 134                                  17.60
# 143                                   8.96
# 147                                   7.33
# 148                                   8.28
# 159                                   1.67
# 167                                  21.38
# 169                                   6.15
# 174                                   7.15

# %%
values_1990=Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (1990)'].isna()]

# %%
values_1990['Metric tons of CO2e per capita (1990)']=values_1990['Metric tons of CO2e per capita (1995)']
values_1990
# Out:
# /var/folders/g_/4y5h37m96h7gb1f4w331kclw0000gn/T/ipykernel_62329/3874575710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_1990['Metric tons of CO2e per capita (1990)']=values_1990['Metric tons of CO2e per capita (1995)']
#     ISO3                 Country Continent           Hemisphere  \
# 6    ARM                 Armenia      Asia  Northern Hemisphere
# 9    AZE              Azerbaijan      Asia  Northern Hemisphere
# 14   BLR                 Belarus    Europe  Northern Hemisphere
# 15   BEL                 Belgium    Europe  Northern Hemisphere
# 20   BIH  Bosnia and Herzegovina    Europe  Northern Hemisphere
# 38   HRV                 Croatia    Europe  Northern Hemisphere
# 41   CZE          Czech Republic    Europe  Northern Hemisphere
# 50   ERI                 Eritrea    Africa  Northern Hemisphere
# 51   EST                 Estonia    Europe  Northern Hemisphere
# 53   ETH                Ethiopia    Africa  Northern Hemisphere
# 59   GEO                 Georgia      Asia  Northern Hemisphere
# 83   KAZ              Kazakhstan      Asia  Northern Hemisphere
# 87   KGZ              Kyrgyzstan      Asia  Northern Hemisphere
# 89   LVA                  Latvia    Europe  Northern Hemisphere
# 94   LTU               Lithuania    Europe  Northern Hemisphere
# 95   LUX              Luxembourg    Europe  Northern Hemisphere
# 105  MDA                 Moldova    Europe  Northern Hemisphere
# 107  MNE              Montenegro    Europe  Northern Hemisphere
# 123  PLW                   Palau   Oceania  Northern Hemisphere
# 134  RUS                  Russia    Europe  Northern Hemisphere
# 143  SRB                  Serbia    Europe  Northern Hemisphere
# 147  SVK                Slovakia    Europe  Northern Hemisphere
# 148  SVN                Slovenia    Europe  Northern Hemisphere
# 159  TJK              Tajikistan      Asia  Northern Hemisphere
# 167  TKM            Turkmenistan      Asia  Northern Hemisphere
# 169  UKR                 Ukraine    Europe  Northern Hemisphere
# 174  UZB              Uzbekistan      Asia  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 6                                     1.94
# 9                                     7.50
# 14                                    8.23
# 15                                     NaN
# 20                                    1.81
# 38                                    4.64
# 41                                   14.05
# 50                                    1.96
# 51                                   14.40
# 53                                    1.11
# 59                                    2.88
# 83                                   14.43
# 87                                    2.06
# 89                                    5.43
# 94                                    6.07
# 95                                     NaN
# 105                                   4.12
# 107                                    NaN
# 123                                   6.98
# 134                                  14.45
# 143                                    NaN
# 147                                   9.36
# 148                                   8.92
# 159                                   1.28
# 167                                  13.39
# 169                                  10.41
# 174                                   7.90
#
#      Metric tons of CO2e per capita (1995)  \
# 6                                     1.94
# 9                                     7.50
# 14                                    8.23
# 15                                     NaN
# 20                                    1.81
# 38                                    4.64
# 41                                   14.05
# 50                                    1.96
# 51                                   14.40
# 53                                    1.11
# 59                                    2.88
# 83                                   14.43
# 87                                    2.06
# 89                                    5.43
# 94                                    6.07
# 95                                     NaN
# 105                                   4.12
# 107                                    NaN
# 123                                   6.98
# 134                                  14.45
# 143                                    NaN
# 147                                   9.36
# 148                                   8.92
# 159                                   1.28
# 167                                  13.39
# 169                                  10.41
# 174                                   7.90
#
#      Metric tons of CO2e per capita (2000)  \
# 6                                     1.82
# 9                                     6.79
# 14                                    7.84
# 15                                   13.26
# 20                                    5.34
# 38                                    5.41
# 41                                   13.76
# 50                                    1.95
# 51                                   13.53
# 53                                    1.09
# 59                                    2.78
# 83                                   10.37
# 87                                    1.85
# 89                                    4.66
# 94                                    5.55
# 95                                   21.14
# 105                                   2.60
# 107                                    NaN
# 123                                   6.74
# 134                                  13.92
# 143                                    NaN
# 147                                   8.48
# 148                                   9.01
# 159                                   0.98
# 167                                  14.51
# 169                                   8.25
# 174                                   8.40
#
#      Metric tons of CO2e per capita (2005)  \
# 6                                     2.30
# 9                                     6.61
# 14                                    8.63
# 15                                   12.16
# 20                                    6.00
# 38                                    6.40
# 41                                   13.47
# 50                                    1.63
# 51                                   15.77
# 53                                    1.16
# 59                                    2.61
# 83                                   13.73
# 87                                    1.97
# 89                                    5.47
# 94                                    6.51
# 95                                   27.86
# 105                                   2.91
# 107                                    NaN
# 123                                  10.30
# 134                                  14.70
# 143                                    NaN
# 147                                   8.68
# 148                                   9.67
# 159                                   1.04
# 167                                  18.13
# 169                                   8.54
# 174                                   7.85
#
#      Metric tons of CO2e per capita (2010)  \
# 6                                     2.46
# 9                                     6.36
# 14                                    9.66
# 15                                   11.44
# 20                                    7.36
# 38                                    5.99
# 41                                   12.39
# 50                                    1.44
# 51                                   17.30
# 53                                    1.31
# 59                                    2.91
# 83                                   17.28
# 87                                    2.16
# 89                                    6.29
# 94                                    6.65
# 95                                   23.82
# 105                                   3.02
# 107                                   5.81
# 123                                  11.64
# 134                                  15.21
# 143                                   6.54
# 147                                   7.90
# 148                                   9.30
# 159                                   1.10
# 167                                  19.44
# 169                                   8.13
# 174                                   7.55
#
#      Metric tons of CO2e per capita (2013)  \
# 6                                     2.97
# 9                                     7.43
# 14                                    9.55
# 15                                   10.17
# 20                                    7.89
# 38                                    5.49
# 41                                   11.42
# 50                                    1.44
# 51                                   17.66
# 53                                    1.30
# 59                                    3.66
# 83                                   18.23
# 87                                    2.73
# 89                                    6.20
# 94                                    6.45
# 95                                   20.72
# 105                                   2.82
# 107                                   5.40
# 123                                  17.03
# 134                                  15.31
# 143                                   6.62
# 147                                   7.43
# 148                                   8.72
# 159                                   1.25
# 167                                  20.93
# 169                                   8.33
# 174                                   7.52
#
#      Metric tons of CO2e per capita (2018)
# 6                                     3.17
# 9                                     8.07
# 14                                    9.29
# 15                                    9.52
# 20                                    8.18
# 38                                    5.52
# 41                                   11.56
# 50                                     NaN
# 51                                   14.07
# 53                                    1.58
# 59                                    4.54
# 83                                   15.00
# 87                                    2.87
# 89                                    6.05
# 94                                    6.73
# 95                                   16.81
# 105                                   4.87
# 107                                   6.11
# 123                                  17.93
# 134                                  17.60
# 143                                   8.96
# 147                                   7.33
# 148                                   8.28
# 159                                   1.67
# 167                                  21.38
# 169                                   6.15
# 174                                   7.15

# %%
Copy_data_set['Metric tons of CO2e per capita (1990)'].fillna(values_1990['Metric tons of CO2e per capita (1990)'],inplace=True)

# %%
Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (1990)'].isna()]
# Out:
#     ISO3     Country Continent           Hemisphere  \
# 15   BEL     Belgium    Europe  Northern Hemisphere
# 95   LUX  Luxembourg    Europe  Northern Hemisphere
# 107  MNE  Montenegro    Europe  Northern Hemisphere
# 143  SRB      Serbia    Europe  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 15                                     NaN
# 95                                     NaN
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (1995)  \
# 15                                     NaN
# 95                                     NaN
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2000)  \
# 15                                   13.26
# 95                                   21.14
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2005)  \
# 15                                   12.16
# 95                                   27.86
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2010)  \
# 15                                   11.44
# 95                                   23.82
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (2013)  \
# 15                                   10.17
# 95                                   20.72
# 107                                   5.40
# 143                                   6.62
#
#      Metric tons of CO2e per capita (2018)
# 15                                    9.52
# 95                                   16.81
# 107                                   6.11
# 143                                   8.96

# %%
Remaing_values=Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (1990)'].isna()]

# %%
Remaining_values=Remaing_values['Metric tons of CO2e per capita (2000)']

# %%
Remaing_values
# Out:
#     ISO3     Country Continent           Hemisphere  \
# 15   BEL     Belgium    Europe  Northern Hemisphere
# 95   LUX  Luxembourg    Europe  Northern Hemisphere
# 107  MNE  Montenegro    Europe  Northern Hemisphere
# 143  SRB      Serbia    Europe  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 15                                     NaN
# 95                                     NaN
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (1995)  \
# 15                                     NaN
# 95                                     NaN
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2000)  \
# 15                                   13.26
# 95                                   21.14
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2005)  \
# 15                                   12.16
# 95                                   27.86
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2010)  \
# 15                                   11.44
# 95                                   23.82
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (2013)  \
# 15                                   10.17
# 95                                   20.72
# 107                                   5.40
# 143                                   6.62
#
#      Metric tons of CO2e per capita (2018)
# 15                                    9.52
# 95                                   16.81
# 107                                   6.11
# 143                                   8.96

# %%
Copy_data_set['Metric tons of CO2e per capita (1990)'].fillna(Remaing_values['Metric tons of CO2e per capita (2000)'],inplace=True)

# %%
Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (1990)'].isna()]
# Out:
#     ISO3     Country Continent           Hemisphere  \
# 107  MNE  Montenegro    Europe  Northern Hemisphere
# 143  SRB      Serbia    Europe  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (1995)  \
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2000)  \
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2005)  \
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2010)  \
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (2013)  \
# 107                                   5.40
# 143                                   6.62
#
#      Metric tons of CO2e per capita (2018)
# 107                                   6.11
# 143                                   8.96

# %%
Copy_data_set['Metric tons of CO2e per capita (1990)'].fillna(Remaing_values['Metric tons of CO2e per capita (2010)'],inplace=True)

# %%
Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (1990)'].isna()]
# Out:
# Empty DataFrame
# Columns: [ISO3, Country, Continent, Hemisphere, Metric tons of CO2e per capita (1990), Metric tons of CO2e per capita (1995), Metric tons of CO2e per capita (2000), Metric tons of CO2e per capita (2005), Metric tons of CO2e per capita (2010), Metric tons of CO2e per capita (2013), Metric tons of CO2e per capita (2018)]
# Index: []

# %%
Copy_data_set['Metric tons of CO2e per capita (1995)'].fillna(Copy_data_set['Metric tons of CO2e per capita (1990)'],inplace=True)

# %%
Copy_data_set['Metric tons of CO2e per capita (1995)'].isna().value_counts()
# Out:
# False    181
# Name: Metric tons of CO2e per capita (1995), dtype: int64

# %%
Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (2000)'].isna()]
# Out:
#     ISO3     Country Continent           Hemisphere  \
# 107  MNE  Montenegro    Europe  Northern Hemisphere
# 143  SRB      Serbia    Europe  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (1995)  \
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (2000)  \
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2005)  \
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2010)  \
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (2013)  \
# 107                                   5.40
# 143                                   6.62
#
#      Metric tons of CO2e per capita (2018)
# 107                                   6.11
# 143                                   8.96

# %%
Copy_data_set['Metric tons of CO2e per capita (2000)'].fillna(Copy_data_set['Metric tons of CO2e per capita (2010)'],inplace=True)

# %%
Copy_data_set['Metric tons of CO2e per capita (2000)'].isna().value_counts()
# Out:
# False    181
# Name: Metric tons of CO2e per capita (2000), dtype: int64

# %%
Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (2005)'].isna()]
# Out:
#     ISO3     Country Continent           Hemisphere  \
# 107  MNE  Montenegro    Europe  Northern Hemisphere
# 143  SRB      Serbia    Europe  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (1995)  \
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (2000)  \
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (2005)  \
# 107                                    NaN
# 143                                    NaN
#
#      Metric tons of CO2e per capita (2010)  \
# 107                                   5.81
# 143                                   6.54
#
#      Metric tons of CO2e per capita (2013)  \
# 107                                   5.40
# 143                                   6.62
#
#      Metric tons of CO2e per capita (2018)
# 107                                   6.11
# 143                                   8.96

# %%
Copy_data_set['Metric tons of CO2e per capita (2005)'].fillna(Copy_data_set['Metric tons of CO2e per capita (2010)'],inplace=True)

# %%
Copy_data_set.isna().value_counts()
# Out:
# ISO3   Country  Continent  Hemisphere  Metric tons of CO2e per capita (1990)  Metric tons of CO2e per capita (1995)  Metric tons of CO2e per capita (2000)  Metric tons of CO2e per capita (2005)  Metric tons of CO2e per capita (2010)  Metric tons of CO2e per capita (2013)  Metric tons of CO2e per capita (2018)
# False  False    False      False       False                                  False                                  False                                  False                                  False                                  False                                  False                                    179
#                                                                                                                                                                                                                                                                                  True                                       1
#                                                                                                                                                                                                                                           True                                   False                                      1
# dtype: int64

# %%
Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (2013)'].isna()]
# Out:
#     ISO3 Country Continent           Hemisphere  \
# 154  SDN   Sudan    Africa  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 154                                   3.83
#
#      Metric tons of CO2e per capita (1995)  \
# 154                                    3.9
#
#      Metric tons of CO2e per capita (2000)  \
# 154                                   4.38
#
#      Metric tons of CO2e per capita (2005)  \
# 154                                   4.57
#
#      Metric tons of CO2e per capita (2010)  \
# 154                                   4.27
#
#      Metric tons of CO2e per capita (2013)  \
# 154                                    NaN
#
#      Metric tons of CO2e per capita (2018)
# 154                                   2.62

# %%
Metric_tons=Copy_data_set[Copy_data_set['Country']=='Sudan']
Metric_tons_2010=Metric_tons['Metric tons of CO2e per capita (2010)']
Metric_tons_2018= Metric_tons['Metric tons of CO2e per capita (2018)']
Avg_sudan=(Metric_tons_2010+Metric_tons_2018)/2
Copy_data_set['Metric tons of CO2e per capita (2013)'].fillna(Avg_sudan,inplace=True)

# %%
Copy_data_set.isna().value_counts()
# Out:
# ISO3   Country  Continent  Hemisphere  Metric tons of CO2e per capita (1990)  Metric tons of CO2e per capita (1995)  Metric tons of CO2e per capita (2000)  Metric tons of CO2e per capita (2005)  Metric tons of CO2e per capita (2010)  Metric tons of CO2e per capita (2013)  Metric tons of CO2e per capita (2018)
# False  False    False      False       False                                  False                                  False                                  False                                  False                                  False                                  False                                    180
#                                                                                                                                                                                                                                                                                  True                                       1
# dtype: int64

# %%
Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (2018)'].isna()]
# Out:
#    ISO3  Country Continent           Hemisphere  \
# 50  ERI  Eritrea    Africa  Northern Hemisphere
#
#     Metric tons of CO2e per capita (1990)  \
# 50                                   1.96
#
#     Metric tons of CO2e per capita (1995)  \
# 50                                   1.96
#
#     Metric tons of CO2e per capita (2000)  \
# 50                                   1.95
#
#     Metric tons of CO2e per capita (2005)  \
# 50                                   1.63
#
#     Metric tons of CO2e per capita (2010)  \
# 50                                   1.44
#
#     Metric tons of CO2e per capita (2013)  \
# 50                                   1.44
#
#     Metric tons of CO2e per capita (2018)
# 50                                    NaN

# %%
Copy_data_set['Metric tons of CO2e per capita (2018)'].fillna(Copy_data_set['Metric tons of CO2e per capita (2013)'],inplace=True)

# %%
Copy_data_set[Copy_data_set['Metric tons of CO2e per capita (2018)'].isna()]
# Out:
# Empty DataFrame
# Columns: [ISO3, Country, Continent, Hemisphere, Metric tons of CO2e per capita (1990), Metric tons of CO2e per capita (1995), Metric tons of CO2e per capita (2000), Metric tons of CO2e per capita (2005), Metric tons of CO2e per capita (2010), Metric tons of CO2e per capita (2013), Metric tons of CO2e per capita (2018)]
# Index: []

# %%
Copy_data_set.isna().value_counts()
# Out:
# ISO3   Country  Continent  Hemisphere  Metric tons of CO2e per capita (1990)  Metric tons of CO2e per capita (1995)  Metric tons of CO2e per capita (2000)  Metric tons of CO2e per capita (2005)  Metric tons of CO2e per capita (2010)  Metric tons of CO2e per capita (2013)  Metric tons of CO2e per capita (2018)
# False  False    False      False       False                                  False                                  False                                  False                                  False                                  False                                  False                                    181
# dtype: int64

# %%
Copy_data_set.describe()
# Out:
#        Metric tons of CO2e per capita (1990)  \
# count                             181.000000
# mean                                6.738785
# std                                 7.589620
# min                                 0.420000
# 25%                                 1.740000
# 50%                                 3.830000
# 75%                                 8.920000
# max                                48.330000
#
#        Metric tons of CO2e per capita (1995)  \
# count                             181.000000
# mean                                6.974530
# std                                 8.794219
# min                                 0.420000
# 25%                                 1.690000
# 50%                                 4.130000
# 75%                                 8.730000
# max                                73.130000
#
#        Metric tons of CO2e per capita (2000)  \
# count                             181.000000
# mean                                7.040166
# std                                 8.590142
# min                                 0.350000
# 25%                                 1.760000
# 50%                                 4.400000
# 75%                                 8.830000
# max                                65.640000
#
#        Metric tons of CO2e per capita (2005)  \
# count                             181.000000
# mean                                7.394972
# std                                 9.289593
# min                                 0.260000
# 25%                                 1.930000
# 50%                                 4.660000
# 75%                                 9.480000
# max                                76.410000
#
#        Metric tons of CO2e per capita (2010)  \
# count                             181.000000
# mean                                7.226464
# std                                 8.239457
# min                                 0.290000
# 25%                                 1.960000
# 50%                                 4.730000
# 75%                                 9.300000
# max                                62.470000
#
#        Metric tons of CO2e per capita (2013)  \
# count                             181.000000
# mean                                7.116436
# std                                 7.883082
# min                                 0.320000
# 25%                                 1.920000
# 50%                                 4.870000
# 75%                                 9.040000
# max                                54.410000
#
#        Metric tons of CO2e per capita (2018)
# count                             181.000000
# mean                                6.765249
# std                                 6.550726
# min                                 0.490000
# 25%                                 2.340000
# 50%                                 4.870000
# 75%                                 8.480000
# max                                38.750000

# %%
Copy_data_set
# Out:
#     ISO3              Country Continent           Hemisphere  \
# 0    AFG          Afghanistan      Asia  Northern Hemisphere
# 1    ALB              Albania    Europe  Northern Hemisphere
# 2    DZA              Algeria    Africa  Northern Hemisphere
# 3    AGO               Angola    Africa  Southern Hemisphere
# 4    ATG  Antigua and Barbuda   America  Northern Hemisphere
# ..   ...                  ...       ...                  ...
# 176  VEN            Venezuela   America  Northern Hemisphere
# 177  VNM              Vietnam      Asia  Northern Hemisphere
# 178  YEM                Yemen      Asia  Northern Hemisphere
# 179  ZMB               Zambia    Africa  Southern Hemisphere
# 180  ZWE             Zimbabwe    Africa  Southern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 0                                     1.24
# 1                                     3.56
# 2                                     3.50
# 3                                     4.29
# 4                                     6.31
# ..                                     ...
# 176                                   8.62
# 177                                   1.03
# 178                                   0.99
# 179                                   5.18
# 180                                   3.25
#
#      Metric tons of CO2e per capita (1995)  \
# 0                                     0.84
# 1                                     2.15
# 2                                     3.42
# 3                                     4.43
# 4                                     6.53
# ..                                     ...
# 176                                   8.73
# 177                                   1.25
# 178                                   1.00
# 179                                   4.20
# 180                                   2.62
#
#      Metric tons of CO2e per capita (2000)  \
# 0                                     0.82
# 1                                     2.36
# 2                                     3.75
# 3                                     4.20
# 4                                     7.08
# ..                                     ...
# 176                                   8.70
# 177                                   1.63
# 178                                   1.15
# 179                                   3.36
# 180                                   2.47
#
#      Metric tons of CO2e per capita (2005)  \
# 0                                     0.76
# 1                                     2.68
# 2                                     4.04
# 3                                     5.06
# 4                                     8.77
# ..                                     ...
# 176                                   8.85
# 177                                   2.16
# 178                                   1.33
# 179                                   3.58
# 180                                   1.93
#
#      Metric tons of CO2e per capita (2010)  \
# 0                                     1.06
# 1                                     2.83
# 2                                     4.58
# 3                                     6.32
# 4                                    10.69
# ..                                     ...
# 176                                   9.08
# 177                                   2.80
# 178                                   1.41
# 179                                   3.31
# 180                                   1.81
#
#      Metric tons of CO2e per capita (2013)  \
# 0                                     1.40
# 1                                     2.85
# 2                                     4.88
# 3                                     5.99
# 4                                    11.22
# ..                                     ...
# 176                                   8.85
# 177                                   2.81
# 178                                   1.39
# 179                                   3.31
# 180                                   1.82
#
#      Metric tons of CO2e per capita (2018)
# 0                                     2.66
# 1                                     3.52
# 2                                     5.18
# 3                                     2.59
# 4                                    12.59
# ..                                     ...
# 176                                   8.10
# 177                                   3.94
# 178                                   0.76
# 179                                   2.34
# 180                                   2.17
#
# [181 rows x 11 columns]

# %% [markdown]
# # 4.  **Data Visualization**

# %%
from matplotlib import pyplot as plt
import seaborn as sns;
import plotly.express as px
import panel as pn

pn.extension('tabulator')
import plotly.graph_objects as go

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='bfbbc96f-1f7d-466c-9835-3bcd93cfa37c'>
#   <div id="c7e33a0f-654d-4f91-8af5-bf8ec6983f1e" data-root-id="bfbbc96f-1f7d-466c-9835-3bcd93cfa37c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"03e01d2d-898d-4e03-9e1c-7d706a9dc1ab":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"bfbbc96f-1f7d-466c-9835-3bcd93cfa37c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"8d51a049-4ba8-49a3-b7fb-7af9fc64ba71","attributes":{"plot_id":"bfbbc96f-1f7d-466c-9835-3bcd93cfa37c","comm_id":"fe758fde8b0a435db3b5d53e2ed1b8df","client_comm_id":"a6444c761d80485f8f3b7fe8e67c73ed"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"03e01d2d-898d-4e03-9e1c-7d706a9dc1ab","roots":{"bfbbc96f-1f7d-466c-9835-3bcd93cfa37c":"c7e33a0f-654d-4f91-8af5-bf8ec6983f1e"},"root_ids":["bfbbc96f-1f7d-466c-9835-3bcd93cfa37c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
numeric_data=Copy_data_set.select_dtypes(include=[np.number])
Correlation_matrix=numeric_data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(Correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The correlations are slightly weaker between non-adjacent years, but they are still very strong. For example, the correlation between 1990 and 2000 is 0.91, and the correlation between 1990 and 2018 is 0.87. This suggests that there is a long-term trend of increasing CO2e emissions per capita.

# %%
numeric_data['Continent']=Copy_data_set['Continent']

# %%
grouped_continent=numeric_data.groupby('Continent').mean()
grouped_continent=grouped_continent.transpose().reset_index()
grouped_continent.rename(columns={'index':'years '})
# Out:
# Continent                                 years     Africa   America  \
# 0          Metric tons of CO2e per capita (1990)  2.900392  6.528000
# 1          Metric tons of CO2e per capita (1995)  2.826471  6.694286
# 2          Metric tons of CO2e per capita (2000)  3.077647  6.833714
# 3          Metric tons of CO2e per capita (2005)  3.392549  7.110857
# 4          Metric tons of CO2e per capita (2010)  3.439608  7.368286
# 5          Metric tons of CO2e per capita (2013)  3.261275  7.505714
# 6          Metric tons of CO2e per capita (2018)  3.185686  6.780286
#
# Continent       Asia    Europe   Oceania
# 0           8.484565  9.765000  7.450909
# 1           9.670435  9.502105  7.092727
# 2           9.698478  9.294737  7.163636
# 3          10.222609  9.690789  7.100000
# 4           9.848696  9.143947  6.742727
# 5           9.868478  8.567368  7.230909
# 6           9.294130  8.260789  7.571818

# %%
melted_df=grouped_continent.melt(id_vars=['index'],value_vars=grouped_continent[1:], var_name="Continent", 
                                       value_name="Emissions")

# %%
plt.figure(figsize=(10,6))
fig=px.line(melted_df,x='index',y='Emissions',color='Continent',title="Mean Emissions by Continent Over the Years",
              labels={"Emissions": "Metric tons of CO2e per capita"})
fig.show()

# %%
Percentage_change=pd.DataFrame()
Africa=(grouped_continent['Africa'][6]-grouped_continent['Africa'][0])/grouped_continent['Africa'][0]*100
Asia=(grouped_continent['Asia'][6]-grouped_continent['Asia'][0])/grouped_continent['Asia'][0]*100
America =(grouped_continent['America'][6]-grouped_continent['America'][0])/grouped_continent['America'][0]*100
Europe =(grouped_continent['Europe'][6]-grouped_continent['Europe'][0])/grouped_continent['Europe'][0]*100
Oceania=(grouped_continent['Oceania'][6]-grouped_continent['Oceania'][0])/grouped_continent['Oceania'][0]*100

# %%
Percentage_change['Continent']=['Africa','Asia','Europe','America','Oceania']

Percentage_change['Co2 Percentage change']=[Africa,Asia,Europe,America,Oceania]
Percentage_change
# Out:
#   Continent  Co2 Percentage change
# 0    Africa               9.836398
# 1      Asia               9.541623
# 2    Europe             -15.404102
# 3   America               3.864671
# 4   Oceania               1.622743

# %%
px.bar(Percentage_change,x='Continent',y='Co2 Percentage change',title='Co2 emissions  percentage change since 1990 ',color='Co2 Percentage change')

# %% [markdown]
#  In a global sprint fueled by carbon, Europe breaks from the pack, running in reverse. Asia and Africa sprint ahead, pushing the climate crisis ever closer, while Europe offers a tantalizing glimpse of a finish line where air is clear and skies are blue.

# %%
grouped_hemisphere=Copy_data_set.groupby('Hemisphere').mean()
grouped_hemisphere=grouped_hemisphere.transpose()
# Out:
# /var/folders/g_/4y5h37m96h7gb1f4w331kclw0000gn/T/ipykernel_62329/3026547066.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
grouped_hemisphere.reset_index(inplace=True)

# %%
grouped_hemisphere['Years']=[1990,1995,2000,2005,2010,2013,2019]

# %%
grouped_hemisphere
# Out:
# Hemisphere                                  index  Northern Hemisphere  \
# 0           Metric tons of CO2e per capita (1990)             7.278681
# 1           Metric tons of CO2e per capita (1995)             7.596250
# 2           Metric tons of CO2e per capita (2000)             7.662083
# 3           Metric tons of CO2e per capita (2005)             8.121875
# 4           Metric tons of CO2e per capita (2010)             7.888333
# 5           Metric tons of CO2e per capita (2013)             7.767118
# 6           Metric tons of CO2e per capita (2018)             7.284444
#
# Hemisphere  Southern Hemisphere  Years
# 0                      4.637568   1990
# 1                      4.554865   1995
# 2                      4.619730   2000
# 3                      4.565946   2005
# 4                      4.650541   2010
# 5                      4.584054   2013
# 6                      4.744595   2019

# %%
melted_df_hemisphere=grouped_hemisphere.melt(id_vars='Years',value_vars=['Northern Hemisphere','Southern Hemisphere'])

# %%
melted_df_hemisphere
# Out:
#     Years           Hemisphere     value
# 0    1990  Northern Hemisphere  7.278681
# 1    1995  Northern Hemisphere  7.596250
# 2    2000  Northern Hemisphere  7.662083
# 3    2005  Northern Hemisphere  8.121875
# 4    2010  Northern Hemisphere  7.888333
# 5    2013  Northern Hemisphere  7.767118
# 6    2019  Northern Hemisphere  7.284444
# 7    1990  Southern Hemisphere  4.637568
# 8    1995  Southern Hemisphere  4.554865
# 9    2000  Southern Hemisphere  4.619730
# 10   2005  Southern Hemisphere  4.565946
# 11   2010  Southern Hemisphere  4.650541
# 12   2013  Southern Hemisphere  4.584054
# 13   2019  Southern Hemisphere  4.744595

# %%
px.line(melted_df_hemisphere,x='Years',y='value',color='Hemisphere')

# %%
Copy_data_set.sort_values(by=['Metric tons of CO2e per capita (2018)'],ascending=False,inplace=True)
Copy_data_set
# Out:
#     ISO3               Country Continent           Hemisphere  \
# 23   BRN                Brunei      Asia  Northern Hemisphere
# 131  QAT                 Qatar      Asia  Northern Hemisphere
# 11   BHR               Bahrain      Asia  Northern Hemisphere
# 170  ARE  United Arab Emirates      Asia  Northern Hemisphere
# 86   KWT                Kuwait      Asia  Northern Hemisphere
# ..   ...                   ...       ...                  ...
# 68   HTI                 Haiti   America  Northern Hemisphere
# 178  YEM                 Yemen      Asia  Northern Hemisphere
# 36   COM               Comoros    Africa  Southern Hemisphere
# 135  RWA                Rwanda    Africa  Southern Hemisphere
# 26   BDI               Burundi    Africa  Southern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 23                                   48.33
# 131                                  29.75
# 11                                   27.27
# 170                                  40.13
# 86                                   37.32
# ..                                     ...
# 68                                    0.66
# 178                                   0.99
# 36                                    0.56
# 135                                   0.52
# 26                                    0.42
#
#      Metric tons of CO2e per capita (1995)  \
# 23                                   46.38
# 131                                  37.30
# 11                                   29.64
# 170                                  38.81
# 86                                   73.13
# ..                                     ...
# 68                                    0.65
# 178                                   1.00
# 36                                    0.53
# 135                                   0.63
# 26                                    0.42
#
#      Metric tons of CO2e per capita (2000)  \
# 23                                   46.49
# 131                                  41.58
# 11                                   29.19
# 170                                  34.89
# 86                                   65.64
# ..                                     ...
# 68                                    0.76
# 178                                   1.15
# 36                                    0.52
# 135                                   0.54
# 26                                    0.35
#
#      Metric tons of CO2e per capita (2005)  \
# 23                                   44.83
# 131                                  52.10
# 11                                   27.78
# 170                                  32.13
# 86                                   76.41
# ..                                     ...
# 68                                    0.81
# 178                                   1.33
# 36                                    0.47
# 135                                   0.56
# 26                                    0.26
#
#      Metric tons of CO2e per capita (2010)  \
# 23                                   46.88
# 131                                  39.13
# 11                                   24.40
# 170                                  23.73
# 86                                   62.47
# ..                                     ...
# 68                                    0.78
# 178                                   1.41
# 36                                    0.50
# 135                                   0.61
# 26                                    0.29
#
#      Metric tons of CO2e per capita (2013)  \
# 23                                   46.84
# 131                                  36.82
# 11                                   25.40
# 170                                  24.59
# 86                                   54.41
# ..                                     ...
# 68                                    0.77
# 178                                   1.39
# 36                                    0.54
# 135                                   0.60
# 26                                    0.32
#
#      Metric tons of CO2e per capita (2018)
# 23                                   38.75
# 131                                  35.89
# 11                                   31.19
# 170                                  27.33
# 86                                   27.31
# ..                                     ...
# 68                                    0.89
# 178                                   0.76
# 36                                    0.71
# 135                                   0.50
# 26                                    0.49
#
# [181 rows x 11 columns]

# %%
Most_poluted_countries=pd.DataFrame(columns=['Country','Metric tons of CO2e per capita (2018)','Hemisphere'])

# %%
Copy_data_set.sort_values(by='Metric tons of CO2e per capita (2018)',ascending=False,inplace=True)
Most_poluted_countries['Country']=Copy_data_set['Country'].head(15)
Most_poluted_countries['Metric tons of CO2e per capita (2018)']=Copy_data_set['Metric tons of CO2e per capita (2018)'].head(15)
Most_poluted_countries['Hemisphere']=Copy_data_set['Hemisphere'].head(15)

# %%
Most_poluted_countries
# Out:
#                   Country  Metric tons of CO2e per capita (2018)  \
# 23                 Brunei                                  38.75
# 131                 Qatar                                  35.89
# 11                Bahrain                                  31.19
# 170  United Arab Emirates                                  27.33
# 86                 Kuwait                                  27.31
# 7               Australia                                  24.63
# 167          Turkmenistan                                  21.38
# 63                Grenada                                  21.14
# 29                 Canada                                  19.56
# 141          Saudi Arabia                                  18.94
# 172         United States                                  18.44
# 123                 Palau                                  17.93
# 134                Russia                                  17.60
# 121                  Oman                                  17.04
# 95             Luxembourg                                  16.81
#
#               Hemisphere
# 23   Northern Hemisphere
# 131  Northern Hemisphere
# 11   Northern Hemisphere
# 170  Northern Hemisphere
# 86   Northern Hemisphere
# 7    Southern Hemisphere
# 167  Northern Hemisphere
# 63   Northern Hemisphere
# 29   Northern Hemisphere
# 141  Northern Hemisphere
# 172  Northern Hemisphere
# 123  Northern Hemisphere
# 134  Northern Hemisphere
# 121  Northern Hemisphere
# 95   Northern Hemisphere

# %%
px.bar(Most_poluted_countries,x='Country',y='Metric tons of CO2e per capita (2018)',color='Metric tons of CO2e per capita (2018)',title='Most polluted counties')

# %%
Copy_data_set
# Out:
#     ISO3               Country Continent           Hemisphere  \
# 23   BRN                Brunei      Asia  Northern Hemisphere
# 131  QAT                 Qatar      Asia  Northern Hemisphere
# 11   BHR               Bahrain      Asia  Northern Hemisphere
# 170  ARE  United Arab Emirates      Asia  Northern Hemisphere
# 86   KWT                Kuwait      Asia  Northern Hemisphere
# ..   ...                   ...       ...                  ...
# 68   HTI                 Haiti   America  Northern Hemisphere
# 178  YEM                 Yemen      Asia  Northern Hemisphere
# 36   COM               Comoros    Africa  Southern Hemisphere
# 135  RWA                Rwanda    Africa  Southern Hemisphere
# 26   BDI               Burundi    Africa  Southern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 23                                   48.33
# 131                                  29.75
# 11                                   27.27
# 170                                  40.13
# 86                                   37.32
# ..                                     ...
# 68                                    0.66
# 178                                   0.99
# 36                                    0.56
# 135                                   0.52
# 26                                    0.42
#
#      Metric tons of CO2e per capita (1995)  \
# 23                                   46.38
# 131                                  37.30
# 11                                   29.64
# 170                                  38.81
# 86                                   73.13
# ..                                     ...
# 68                                    0.65
# 178                                   1.00
# 36                                    0.53
# 135                                   0.63
# 26                                    0.42
#
#      Metric tons of CO2e per capita (2000)  \
# 23                                   46.49
# 131                                  41.58
# 11                                   29.19
# 170                                  34.89
# 86                                   65.64
# ..                                     ...
# 68                                    0.76
# 178                                   1.15
# 36                                    0.52
# 135                                   0.54
# 26                                    0.35
#
#      Metric tons of CO2e per capita (2005)  \
# 23                                   44.83
# 131                                  52.10
# 11                                   27.78
# 170                                  32.13
# 86                                   76.41
# ..                                     ...
# 68                                    0.81
# 178                                   1.33
# 36                                    0.47
# 135                                   0.56
# 26                                    0.26
#
#      Metric tons of CO2e per capita (2010)  \
# 23                                   46.88
# 131                                  39.13
# 11                                   24.40
# 170                                  23.73
# 86                                   62.47
# ..                                     ...
# 68                                    0.78
# 178                                   1.41
# 36                                    0.50
# 135                                   0.61
# 26                                    0.29
#
#      Metric tons of CO2e per capita (2013)  \
# 23                                   46.84
# 131                                  36.82
# 11                                   25.40
# 170                                  24.59
# 86                                   54.41
# ..                                     ...
# 68                                    0.77
# 178                                   1.39
# 36                                    0.54
# 135                                   0.60
# 26                                    0.32
#
#      Metric tons of CO2e per capita (2018)
# 23                                   38.75
# 131                                  35.89
# 11                                   31.19
# 170                                  27.33
# 86                                   27.31
# ..                                     ...
# 68                                    0.89
# 178                                   0.76
# 36                                    0.71
# 135                                   0.50
# 26                                    0.49
#
# [181 rows x 11 columns]

# %%
Copy_data_set['Pecentage_change_countries']=(Copy_data_set['Metric tons of CO2e per capita (2018)']-Copy_data_set['Metric tons of CO2e per capita (1990)'])/Copy_data_set['Metric tons of CO2e per capita (1990)']*100

# %%
Copy_data_set.sort_values(by='Pecentage_change_countries',ascending=False,inplace=True)

# %%
px.bar(data_frame=Copy_data_set,x=Copy_data_set['Country'].head(10),y=Copy_data_set['Pecentage_change_countries'].head(10),color=Copy_data_set['Continent'].head(10),title='Countries with highest change in CO2 emssions since 1990 ')

# %%
px.bar(data_frame=Copy_data_set,x=Copy_data_set['Country'].tail(10),y=Copy_data_set['Pecentage_change_countries'].tail(10),color=Copy_data_set['Continent'].tail(10),
title='Countries with lowest change in CO2 emssions since 1990 ')

# %%
Copy_data_set
# Out:
#     ISO3                 Country Continent           Hemisphere  \
# 49   GNQ       Equatorial Guinea    Africa  Northern Hemisphere
# 99   MDV                Maldives      Asia  Northern Hemisphere
# 20   BIH  Bosnia and Herzegovina    Europe  Northern Hemisphere
# 177  VNM                 Vietnam      Asia  Northern Hemisphere
# 92   LBR                 Liberia    Africa  Northern Hemisphere
# ..   ...                     ...       ...                  ...
# 179  ZMB                  Zambia    Africa  Southern Hemisphere
# 112  NRU                   Nauru   Oceania  Southern Hemisphere
# 58   GMB                  Gambia    Africa  Northern Hemisphere
# 119  PRK             North Korea      Asia  Northern Hemisphere
# 16   BLZ                  Belize   America  Northern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 49                                    0.52
# 99                                    0.84
# 20                                    1.81
# 177                                   1.03
# 92                                    0.57
# ..                                     ...
# 179                                   5.18
# 112                                  14.23
# 58                                    4.08
# 119                                   7.68
# 16                                   29.05
#
#      Metric tons of CO2e per capita (1995)  \
# 49                                    2.70
# 99                                    1.19
# 20                                    1.81
# 177                                   1.25
# 92                                    0.45
# ..                                     ...
# 179                                   4.20
# 112                                  11.02
# 58                                    4.13
# 119                                   4.92
# 16                                   29.84
#
#      Metric tons of CO2e per capita (2000)  \
# 49                                   13.89
# 99                                    1.83
# 20                                    5.34
# 177                                   1.63
# 92                                    0.41
# ..                                     ...
# 179                                   3.36
# 112                                   8.86
# 58                                    4.14
# 119                                   4.12
# 16                                   28.55
#
#      Metric tons of CO2e per capita (2005)  \
# 49                                   25.83
# 99                                    2.10
# 20                                    6.00
# 177                                   2.16
# 92                                    0.48
# ..                                     ...
# 179                                   3.58
# 112                                   6.71
# 58                                    4.13
# 119                                   4.27
# 16                                   28.11
#
#      Metric tons of CO2e per capita (2010)  \
# 49                                   21.33
# 99                                    2.69
# 20                                    7.36
# 177                                   2.80
# 92                                    0.48
# ..                                     ...
# 179                                   3.31
# 112                                   4.94
# 58                                    4.26
# 119                                   3.83
# 16                                   28.29
#
#      Metric tons of CO2e per capita (2013)  \
# 49                                   19.15
# 99                                    2.86
# 20                                    7.89
# 177                                   2.81
# 92                                    0.50
# ..                                     ...
# 179                                   3.31
# 112                                   4.53
# 58                                    4.02
# 119                                   2.55
# 16                                   28.15
#
#      Metric tons of CO2e per capita (2018)  Pecentage_change_countries
# 49                                   14.72                 2730.769231
# 99                                    4.61                  448.809524
# 20                                    8.18                  351.933702
# 177                                   3.94                  282.524272
# 92                                    1.91                  235.087719
# ..                                     ...                         ...
# 179                                   2.34                  -54.826255
# 112                                   6.03                  -57.624736
# 58                                    1.22                  -70.098039
# 119                                   1.64                  -78.645833
# 16                                    4.08                  -85.955250
#
# [181 rows x 12 columns]

# %%
Main_data_set
# Out:
#     ISO3              Country Continent           Hemisphere  \
# 0    AFG          Afghanistan      Asia  Northern Hemisphere
# 1    ALB              Albania    Europe  Northern Hemisphere
# 2    DZA              Algeria    Africa  Northern Hemisphere
# 3    AGO               Angola    Africa  Southern Hemisphere
# 4    ATG  Antigua and Barbuda   America  Northern Hemisphere
# ..   ...                  ...       ...                  ...
# 176  VEN            Venezuela   America  Northern Hemisphere
# 177  VNM              Vietnam      Asia  Northern Hemisphere
# 178  YEM                Yemen      Asia  Northern Hemisphere
# 179  ZMB               Zambia    Africa  Southern Hemisphere
# 180  ZWE             Zimbabwe    Africa  Southern Hemisphere
#
#      Metric tons of CO2e per capita (1990)  \
# 0                                     1.24
# 1                                     3.56
# 2                                     3.50
# 3                                     4.29
# 4                                     6.31
# ..                                     ...
# 176                                   8.62
# 177                                   1.03
# 178                                   0.99
# 179                                   5.18
# 180                                   3.25
#
#      Metric tons of CO2e per capita (1995)  \
# 0                                     0.84
# 1                                     2.15
# 2                                     3.42
# 3                                     4.43
# 4                                     6.53
# ..                                     ...
# 176                                   8.73
# 177                                   1.25
# 178                                   1.00
# 179                                   4.20
# 180                                   2.62
#
#      Metric tons of CO2e per capita (2000)  \
# 0                                     0.82
# 1                                     2.36
# 2                                     3.75
# 3                                     4.20
# 4                                     7.08
# ..                                     ...
# 176                                   8.70
# 177                                   1.63
# 178                                   1.15
# 179                                   3.36
# 180                                   2.47
#
#      Metric tons of CO2e per capita (2005)  \
# 0                                     0.76
# 1                                     2.68
# 2                                     4.04
# 3                                     5.06
# 4                                     8.77
# ..                                     ...
# 176                                   8.85
# 177                                   2.16
# 178                                   1.33
# 179                                   3.58
# 180                                   1.93
#
#      Metric tons of CO2e per capita (2010)  \
# 0                                     1.06
# 1                                     2.83
# 2                                     4.58
# 3                                     6.32
# 4                                    10.69
# ..                                     ...
# 176                                   9.08
# 177                                   2.80
# 178                                   1.41
# 179                                   3.31
# 180                                   1.81
#
#      Metric tons of CO2e per capita (2013)  \
# 0                                     1.40
# 1                                     2.85
# 2                                     4.88
# 3                                     5.99
# 4                                    11.22
# ..                                     ...
# 176                                   8.85
# 177                                   2.81
# 178                                   1.39
# 179                                   3.31
# 180                                   1.82
#
#      Metric tons of CO2e per capita (2018)
# 0                                     2.66
# 1                                     3.52
# 2                                     5.18
# 3                                     2.59
# 4                                    12.59
# ..                                     ...
# 176                                   8.10
# 177                                   3.94
# 178                                   0.76
# 179                                   2.34
# 180                                   2.17
#
# [181 rows x 11 columns]

# %% [markdown]
# # 5. **Conclusion**

# %% [markdown]
# Conclusion
# From the analysis, it can be concluded that
# * Asia has the highest carbon footprint, followed by Africa.
# * Europe is the only continent with a negative net annual CO2 emissions release.
# * The Northern Hemisphere exhibits substantially higher CO2 emissions compared to the Southern Hemisphere, likely due to its composition of four major continents.
# * Although Asia currently leads in carbon footprint, Africa is making strides to catch up.
